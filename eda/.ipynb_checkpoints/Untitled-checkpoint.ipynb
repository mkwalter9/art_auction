# %%
import os, sys
import pandas as pd
import numpy as np
import json

REL_DATA_PATH = '../data_collection/records'

# %%
sys.path.append(REL_DATA_PATH)

# %%
data_files=os.listdir(REL_DATA_PATH)

# %%
data_files
# Out:
# ['artist_dataset_1603770872.7226639.csv',
#  'artist_dataset_1603769378.010896.csv',
#  'artist_dataset_1603769680.807018.csv',
#  'artist_dataset_1603771134.534486.csv']

# %%
df = pd.DataFrame()
for n in data_files:
    df=df.append(pd.read_csv(f"{REL_DATA_PATH}/{n}",sep='|').drop('Unnamed: 0',axis=1))

# %%
df.describe(include='all')
# Out:
#          Unnamed: 0 Category  Year Created Surface Substrate Signature  \
# count   5444.000000     5444   4010.000000    4857      4853      5444
# unique          NaN        4           NaN     438       149         3
# top             NaN       2D           NaN     Oil     Paper       Yes
# freq            NaN     4823           NaN    1773      2436      3900
# mean     414.925606      NaN   1946.747382     NaN       NaN       NaN
# std      472.746489      NaN    318.704065     NaN       NaN       NaN
# min        0.000000      NaN   1630.000000     NaN       NaN       NaN
# 25%       49.000000      NaN   1917.000000     NaN       NaN       NaN
# 50%      211.000000      NaN   1951.000000     NaN       NaN       NaN
# 75%      677.000000      NaN   1969.000000     NaN       NaN       NaN
# max     1758.000000      NaN  21964.000000     NaN       NaN       NaN
#
#              Image Size                                            img_url  \
# count              5354                                               5314
# unique             3945                                               5063
# top     29.25 x 43 inch  https://artbnk-art-resized-images.s3.amazonaws...
# freq                 57                                                124
# mean                NaN                                                NaN
# std                 NaN                                                NaN
# min                 NaN                                                NaN
# 25%                 NaN                                                NaN
# 50%                 NaN                                                NaN
# 75%                 NaN                                                NaN
# max                 NaN                                                NaN
#
#            Title       Artist Name  \
# count       5444              5444
# unique      4080                47
# top     Untitled  ALEXANDER CALDER
# freq         430              1759
# mean         NaN               NaN
# std          NaN               NaN
# min          NaN               NaN
# 25%          NaN               NaN
# 50%          NaN               NaN
# 75%          NaN               NaN
# max          NaN               NaN
#
#                                                image_file Medium
# count                                                5314    578
# unique                                               5103     95
# top     images/affandi/8f8481e6531eb3a73214cdbf050be6d...   Wire
# freq                                                   35     81
# mean                                                  NaN    NaN
# std                                                   NaN    NaN
# min                                                   NaN    NaN
# 25%                                                   NaN    NaN
# 50%                                                   NaN    NaN
# 75%                                                   NaN    NaN
# max                                                   NaN    NaN

# %%
df
# Out:
#      Unnamed: 0 Category  Year Created      Surface      Substrate Signature  \
# 0             0       2D        1835.0   Brush, Pen          Paper       Yes
# 1             1       2D        1837.0          Oil         Canvas       Yes
# 2             2       2D           NaN          Oil          Panel       Yes
# 3             3       2D        1815.0          Oil         Canvas       Yes
# 4             4       2D           NaN          Oil          Panel       Yes
# ..          ...      ...           ...          ...            ...       ...
# 783          99       2D        1882.0  Watercolour          Paper   Unknown
# 784         100       2D        1884.0          Oil  Canvas, Panel   Unknown
# 785         101       2D        1884.0          Oil  Canvas, Panel   Unknown
# 786         102       2D        1887.0          Oil         Canvas   Unknown
# 787         103       2D        1887.0          Oil         Canvas   Unknown
#
#               Image Size                                            img_url  \
# 0         28.6 x 19.7 cm  https://artbnk-art-resized-images.s3.amazonaws...
# 1     10.25 x 14.75 inch  https://artbnk-art-resized-images.s3.amazonaws...
# 2         17.5 x 30 inch  https://artbnk-art-resized-images.s3.amazonaws...
# 3     13.62 x 10.75 inch  https://artbnk-art-resized-images.s3.amazonaws...
# 4    20.125 x 30.75 inch  https://artbnk-art-resized-images.s3.amazonaws...
# ..                   ...                                                ...
# 783                  NaN  https://artbnk-art-resized-images.s3.amazonaws...
# 784  15.375 x 16.75 inch  https://artbnk-art-resized-images.s3.amazonaws...
# 785     15.5 x 11.5 inch  https://artbnk-art-resized-images.s3.amazonaws...
# 786    21.5 x 26.25 inch  https://artbnk-art-resized-images.s3.amazonaws...
# 787    21.5 x 26.25 inch  https://artbnk-art-resized-images.s3.amazonaws...
#
#                                                Title        Artist Name  \
# 0                         Mountain Stream in Norway.  ANDREAS ACHENBACH
# 1                             Norwegische Landschaft  ANDREAS ACHENBACH
# 2                                     Boote im Hafen  ANDREAS ACHENBACH
# 3                            Sunset on a Rocky Coast  ANDREAS ACHENBACH
# 4                              Heissische Landschaft  ANDREAS ACHENBACH
# ..                                               ...                ...
# 783                                The Potato Market   VINCENT VAN GOGH
# 784   Nature morte aux pinceaux dans un pot à fleurs   VINCENT VAN GOGH
# 785                              Peasant Woman, Head   VINCENT VAN GOGH
# 786  L'Avenue au parc de Voyer-d'Argenson à Asnières   VINCENT VAN GOGH
# 787  L'Entrée de parc de Voyer-d'Argenson à Asnières   VINCENT VAN GOGH
#
#                                             image_file Medium
# 0    images/andreas_achenbach/db71d17c6b99bbcb339c6...    NaN
# 1    images/andreas_achenbach/31cabcab5d8ab2fc3433e...    NaN
# 2    images/andreas_achenbach/529bbbcbc6021af2efdf8...    NaN
# 3    images/andreas_achenbach/3db9605b25d95b10ec099...    NaN
# 4    images/andreas_achenbach/2f4da8689c5df799c7e20...    NaN
# ..                                                 ...    ...
# 783  images/vincent_van_gogh/f4488cf70705c131236ca2...    NaN
# 784  images/vincent_van_gogh/656fff066edb7b6a2be3cd...    NaN
# 785  images/vincent_van_gogh/824c3c0605052b762a6dcb...    NaN
# 786  images/vincent_van_gogh/fa7b9e34247d1c3b9c41ce...    NaN
# 787  images/vincent_van_gogh/26e4e49626aa7af11c9848...    NaN
#
# [5444 rows x 12 columns]
